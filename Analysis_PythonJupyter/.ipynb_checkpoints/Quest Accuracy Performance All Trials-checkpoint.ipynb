# %% [markdown]
# ## Load Libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import os
import time as tm

# %% [markdown]
# ## Load Data

# %%
# path = "C:/Users/galeaj-admin/AppData/LocalLow/DefaultCompany/QuestHandTrackingTest/ptx_07_joe/"
# path = "C:/Users/galeaj-admin/Downloads/QuestTrackingAccuracy-main/QuestTrackingAccuracy-main/ptx_07_joe/"
# fileName = "pilot_007_h1_Target_row_C2_Trial_16_.json"

# path = "C:/Users/ActionLab/AppData/LocalLow/DefaultCompany/QuestHandTrackingTest/" 
# fileName = "1628774990_fa41v_Target_row_B3_Trial_11_.json"

# path = "C:/Users/ActionLab/Desktop/QuestTrackingData/Poppy_1st_Sep_2021/"
path = "C:/Users/ActionLab/Desktop/QuestTrackingData/Max_3rd_Sep_2021/"

# df = pd.read_json(path + fileName)

# %%
allFiles = os.listdir(path)
dataFrame = None
heightVar = ''
bmpVar = ''

for i in allFiles:
    tempFrame = pd.read_json(path + i)
    
#     tempSplit = str.split(i,'_')
#     if 'high' is in tempSplit | 'low' is in tempSplit | 'mid' is in tempSplit | 'medium' is in tempSplit:
#         # find the index of the find and attach it to the appropriate variable so that it can be added to the dataframe
        
    
    if dataFrame is None:
        dataFrame = tempFrame
    else:
        dataFrame = pd.concat([dataFrame,tempFrame])

# %%
dataFrame
# Out:
#       trialNumber  frameNum             gameObjectName      xPos      yPos  \
# 0               0         0              realFingerTip -0.842714  0.292738
# 1               0         0             b_r_index_null -0.845475  0.291552
# 2               0         0  r_index_fingernail_marker -0.844435  0.296870
# 3               0         0  r_index_finger_tip_marker -0.845917  0.290783
# 4               0         0  r_index_finger_pad_marker -0.846679  0.285429
# ...           ...       ...                        ...       ...       ...
# 1845           72        87                 b_r_index3 -0.306271  0.591937
# 1846           72        87                 b_r_index2 -0.323449  0.596995
# 1847           72        87                 b_r_index1 -0.350065  0.604149
# 1848           72        87                  b_r_wrist -0.409883  0.623697
# 1849           72        87            CenterEyeAnchor -0.813565  0.957860
#
# ...

# %% [markdown]
# ## Plot data

# %%
# xPos = df.xPos[df.gameObjectName[df.gameObjectName == 'b_r_index_null']]
# zPos = df.zPos[df.gameObjectName[df.gameObjectName == 'b_r_index_null']]
xPos = None

xPos = dataFrame.loc[(dataFrame['gameObjectName'] == 'b_r_index_null') & (dataFrame['targetID'] == 'row_A4') & (dataFrame['targetID'] == 'row_A4'), ['xPos']]
zPos = dataFrame.loc[(dataFrame['gameObjectName'] == 'b_r_index_null') & (dataFrame['targetID'] == 'row_A4') & (dataFrame['targetID'] == 'row_A4'), ['zPos']]
xPosM = dataFrame.loc[(dataFrame['gameObjectName'] == 'realFingerTip') & (dataFrame['targetID'] == 'row_A4') & (dataFrame['targetID'] == 'row_A4'), ['xPos']]
zPosM = dataFrame.loc[(dataFrame['gameObjectName'] == 'realFingerTip') & (dataFrame['targetID'] == 'row_A4') & (dataFrame['targetID'] == 'row_A4'), ['zPos']]
time = dataFrame.loc[(dataFrame['gameObjectName'] == 'realFingerTip') &  (dataFrame['targetID'] == 'row_A4') & (dataFrame['targetID'] == 'row_A4'),  ['time']]

tposX = dataFrame.loc[(dataFrame['gameObjectName'] == 'b_r_index_null') & (dataFrame['targetID'] == 'row_A4'), ['xTPos', 'trialNumber']]
tposY = dataFrame.loc[(dataFrame['gameObjectName'] == 'b_r_index_null') & (dataFrame['targetID'] == 'row_A4'), ['yTPos', 'trialNumber']]
tposZ = dataFrame.loc[(dataFrame['gameObjectName'] == 'b_r_index_null') & (dataFrame['targetID'] == 'row_A4'), ['zTPos', 'trialNumber']]

# plt.plot(xPos,'r')
# plt.plot(zPos,'g')
plt.plot(xPos,zPos,'r')
plt.plot(xPosM,zPosM,'k')
plt.plot(tposX, tposZ, 'm-o')

# plt.plot(xPosM,'k')
# plt.plot(df.time*0.1,'b')
# plt.plot(df.frameNum*0.01,'k')
#plt.legend(['Hand','Target'])
plt.title('X-Z Trajectories')
plt.legend(["Quest_X","Marker_X", "Target"])
plt.xlabel('X Axis')
plt.ylabel('Z Axis')
plt.show()

# %%
xPosMean = xPos.groupby('xPos', as_index=False)['trialNumber'].mean()

uniqueTrialNums = pd.unique(xPos.trialNumber)

xValTotLen = 0
for i in uniqueTrialNums:
    xVals = xPos.loc[(xPos['trialNumber'] == i), ['xPos']]
    plt.plot(xVals)
    xValTotLen += len(xVals)

# %%
# # Visualize the result
# plt.plot(xdata, ydata, 'or')
# plt.plot(xfit, yfit, '-', color='gray')

# plt.fill_between(xfit, yfit - dyfit, yfit + dyfit,
#                  color='gray', alpha=0.2)

xPos.head
# Out:
# <bound method NDFrame.head of           xPos
# 1    -0.835282
# 11   -0.832996
# 21   -0.831203
# 31   -0.829774
# 41   -0.828297
# ...        ...
# 991  -0.740135
# 1001 -0.740328
# 1011 -0.740436
# 1021 -0.739941
# 1031 -0.739523
#
# [4531 rows x 1 columns]>

# %%
# t = np.diff(time)
# # plt.plot(t[40:],'b')
# plt.plot(time,'b')

# %%
from scipy.signal import savgol_filter

print("Original number of values", np.shape(xPos))
print("Unique quest", np.shape(np.unique(xPos)))
print("Unique marker", np.shape(np.unique(xPosM)))

sxPos = savgol_filter(xPos, 51, 3)
sxPosM = savgol_filter(xPosM, 51, 3)
                       
plt.plot(np.gradient(sxPos),'r')
plt.plot(np.gradient(sxPosM),'g')
plt.plot(np.gradient(xPos),'c')
plt.plot(np.gradient(xPosM),'m')

plt.title("Smoothed and Raw Velocity")
plt.legend(["Smoothed Quest_X","Smoothed Marker_X","Raw Quest_X","Raw Marker_X"])

plt.figure()
t = np.diff(time)
# plt.plot(t[40:],'b')
plt.plot(time,'b')
print('Time length: ', np.shape(time))
# Out:
# Original number of values (4531, 1)
# Unique quest (4498,)
# Unique marker (2956,)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-50-04cab6e5a757> in <module>
#       5 print("Unique marker", np.shape(np.unique(xPosM)))
#       6
# ----> 7 sxPos = savgol_filter(xPos, 51, 3)
#       8 sxPosM = savgol_filter(xPosM, 51, 3)
#       9
#
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\signal\_savitzky_golay.py in savgol_filter(x, window_length, polyorder, deriv, delta, axis, mode, cval)
#     344         # the last `window_length` elements.
#     345         y = convolve1d(x, coeffs, axis=axis, mode="constant")
# --> 346         _fit_edges_polyfit(x, window_length, polyorder, deriv, delta, axis, y)
#     347     else:
#     348         # Any mode other than 'interp' is passed on to ndimage.convolve1d.
#
# ...

# %%
import math
import sys

import numpy as np
import numpy.linalg
import pylab as py

def sg_filter(x, m, k=0):
    """
    x = Vector of sample times
    m = Order of the smoothing polynomial
    k = Which derivative
    """
    mid = len(x) / 2        
    a = x - x[mid]
    expa = lambda x: map(lambda i: i**x, a)    
    A = np.r_[map(expa, range(0,m+1))].transpose()
    Ai = np.linalg.pinv(A)

    return Ai[k]

def smooth(x, y, size=5, order=2, deriv=0):
    
#     if deriv > order:
#         raise Exception, "deriv must be <= order"

    n = len(x)
    m = size

    result = np.zeros(n)

    for i in xrange(m, n-m):
        start, end = i - m, i + m + 1
        f = sg_filter(x[start:end], order, deriv)
        result[i] = np.dot(f, y[start:end])

    if deriv > 1:
        result *= math.factorial(deriv)

    return result
